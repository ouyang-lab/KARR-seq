# %%
import matplotlib
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42

import matplotlib.pyplot as plt
import sys

sys.path.append("..")
from analysis.visualize.utils_contactmap import plot_contactmap_w_arcbands

# %% [markdown]
# ## Contact Maps
# Comparing the contact maps of Eef1g from mouse embryonic stem cells (mESC F123) and EEF1G from human liver cancer cell line (HepG2). Samples were derived from denatured and renatured RNA (in vitro), i.e. as close to probing sequence derived secondary structure not disturbed by any cellular factors or processes (RBP or translation)

# %% [markdown]
# ### Eef1g (mESC)

# %%
data_mouse = ["../data/pairs/se/refseq/MAPQ1_SPAN0/G1_kethoxal-mESC-refold_M13_R01.dedup.pairs.gz", 
              "../data/pairs/se/refseq/MAPQ1_SPAN0/G1_kethoxal-mESC-refold_M13_R02.dedup.pairs.gz"]

f_cluster_mouse = "../data/clustering/output/refseq/G1_kethoxal-mESC-refold_M13_C01.dedup.classification.txt"

plot_contactmap_w_arcbands(data_mouse, f_cluster_mouse, p_chrom1="NM_026007.4", p_resolution=25, p_max=3, p_figsize=(10, 10),
                           p_structure=True, p_genome=None, p_display="upper", p_balance=False,
                           f_fasta = "../data/reference/mm10/mm10_refseq.fa",
                           f_size = "../data/reference/mm10/mm10_refseq.sizes",
                           p_dot_size=1.0, p_multi=False, p_verbose=False)
# Out:
# (<Figure size 720x720 with 3 Axes>, array([[<AxesSubplot:>]], dtype=object))

# %% [markdown]
# ### EEF1G (HepG2)

# %%
data_human = ["../data/pairs/se/hrefseq/MAPQ1_SPAN0/G1_kethoxal-HepG2-refold_M13_R01.dedup.pairs.gz", 
              "../data/pairs/se/hrefseq/MAPQ1_SPAN0/G1_kethoxal-HepG2-refold_M13_R02.dedup.pairs.gz"]
f_cluster_human = "../data/clustering/output/hrefseq/G1_kethoxal-HepG2-refold_M13_C01.dedup.classification.txt"

plot_contactmap_w_arcbands(data_human, f_cluster_human, p_chrom1="NM_001404", p_resolution=25, p_max=3, p_figsize=(10, 10),
                           p_structure=True, p_genome=None, p_display="upper", p_balance=False,
                           f_fasta = "../data/reference/hg19/hg19_refseq_wo_version.fasta",
                           f_size = "../data/reference/hg19/hg19_refseq_wo_version.sizes",
                           p_dot_size=1.0, p_multi=False, p_verbose=False)
# Out:
# (<Figure size 720x720 with 3 Axes>, array([[<AxesSubplot:>]], dtype=object))
