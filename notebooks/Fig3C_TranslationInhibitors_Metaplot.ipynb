# %%
import sys

sys.path.append("..")
from analysis.meta.plot_metagene_from_refseq import plot_metagene

# %%
p_app = "metagene"
p_genomes = ["hg19", "hg19", "hg19", "hg19"]
f_bigWigs = ["../analysis/meta/data/bigWig/G1_kethoxal-HepG2_M13_R01_intra.bigWig",
             "../analysis/meta/data/bigWig/G1_kethoxal-HepG2-refold_M13_R01_intra.bigWig",
             "../analysis/meta/data/bigWig/G1_kethoxal-HepG2-HT_M13_R01_intra.bigWig",
             "../analysis/meta/data/bigWig/G1_kethoxal-HepG2-CHX_M13_R01_intra.bigWig"]
f_output = None

p_labels = ["HepG2 in-vivo", "HepG2 in-vitro",
            "HepG2 HT", "HepG2 CHX"]
p_colors = ["#1266ed", "#4286f4", "#c41d1d", "#e86f6f"]
p_markers = ["-o", "-^", "-s", "-*"]
p_bins = 10

plot_metagene(p_app, p_genomes, f_bigWigs, f_output, p_labels, p_colors, p_markers, p_bins)
