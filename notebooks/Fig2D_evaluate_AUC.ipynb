# %%
import matplotlib
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42

import matplotlib.pyplot as plt
import sys

sys.path.append("..")
from analysis.validation.evaluate_AUC import main as plot_AUC

# %% [markdown]
# ### TERC

# %%
f_pairs = ["../data/ligated/se/hrefseq/MAPQ1_SPAN0/G1_kethoxal-HEK293T_M13_B01.dedup.pairs.gz",
           "../data/ligated/se/hrefseq/MAPQ1_SPAN0/PARIS-HEK293T_B97_B01.nodedup.pairs.gz",
           "../data/ligated/se/hrefseq/MAPQ1_SPAN0/RIC-HeLa-rRNA-_M94_B01.dedup.pairs.gz"]

# %%
chrom = "NR_001566"

p_chrom1 = chrom
p_gamma_k = [6]
p_mean_u = 20
p_labels = ["KARR-seq (HEK293T)", "PARIS (HEK293T)", "RIC-seq (HeLa)"]
f_output = None

plot_AUC(f_output=f_output, f_pairs=f_pairs, f_prefix=None,
         p_resolution=10, p_display="full", p_genome="hg19",
         p_chrom1=p_chrom1, p_start1=None, p_end1=None,
         p_chrom2=None, p_start2=None, p_end2=None,
         p_downsample=1.0, p_method="auc", 
         p_gamma_k=p_gamma_k, p_mean_u=p_mean_u, 
         p_lower=0.1, p_upper=0.9, 
         p_labels=p_labels, p_col=1)

# %% [markdown]
# ### 28S

# %%
f_pairs = ["../data/ligated/se/hcanonical_h+y/MAPQ1_SPAN0/G1_kethoxal-HepG2-TotalRNA_M19_R01.dedup.pairs.gz",
           "../data/ligated/se/hcanonical_h+y/MAPQ1_SPAN0/PARIS-HEK293T_M97_R01.nodedup.pairs.gz",
           "../data/ligated/se/hcanonical_h+y/MAPQ1_SPAN0/RIC-HeLa-Total_M95_R01.dedup.pairs.gz"]

# %%
chrom = "human-4V6X-28S"

p_chrom1 = chrom
p_gamma_k = [6]
p_mean_u = 20
p_labels = ["KARR-seq (HEK293T)", "PARIS (HEK293T)", "RIC-seq (HeLa)"]
f_output = None

plot_AUC(f_output=f_output, f_pairs=f_pairs, f_prefix=None,
         p_resolution=5, p_display="full", p_genome="canonical_h+y",
         p_chrom1=p_chrom1, p_start1=None, p_end1=None,
         p_chrom2=None, p_start2=None, p_end2=None,
         p_downsample=1.0, p_method="auc", 
         p_gamma_k=p_gamma_k, p_mean_u=p_mean_u, 
         p_lower=0.1, p_upper=0.9, 
         p_labels=p_labels, p_col=1)

# %% [markdown]
# ### U1

# %%
f_pairs = ["../data/ligated/se/hcanonical_h+y/MAPQ1_SPAN0/G1_kethoxal-K562_M15_R01.dedup.pairs.gz",
           "../data/ligated/se/hcanonical_h+y/MAPQ1_SPAN0/PARIS-HEK293T_M97_R01.nodedup.pairs.gz",
           "../data/ligated/se/hcanonical_h+y/MAPQ1_SPAN0/RIC-HeLa-rRNA-_M94_R01.dedup.pairs.gz"]

# %%
chrom = "hsnrna-RNU1-1"

p_chrom1 = chrom
p_gamma_k = [6]
p_mean_u = 20
p_labels = ["KARR-seq (HEK293T)", "PARIS (HEK293T)", "RIC-seq (HeLa)"]
f_output = None

plot_AUC(f_output=f_output, f_pairs=f_pairs, f_prefix=None,
         p_resolution=5, p_display="full", p_genome="canonical_h+y",
         p_chrom1=p_chrom1, p_start1=None, p_end1=None,
         p_chrom2=None, p_start2=None, p_end2=None,
         p_downsample=1.0, p_method="auc", 
         p_gamma_k=p_gamma_k, p_mean_u=p_mean_u, 
         p_lower=0.1, p_upper=0.9, 
         p_labels=p_labels, p_col=1)
